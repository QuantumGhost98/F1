# %%
import fastf1.plotting
import f1analytics as f1

# %%
fastf1.plotting.setup_mpl(color_scheme='fastf1')

session_year = 2025
session_name = "Baku Grand Prix"

# Load FP2 session
fp2_session_type = 'FP2'
fp2_session = fastf1.get_session(session_year, session_name, fp2_session_type)
fp2_session.load()

# Load Qualifying session (your current session)
q_session_type = 'Q'
q_session = fastf1.get_session(session_year, session_name, q_session_type)
q_session.load()
# Out:
# core           INFO 	Loading data for Azerbaijan Grand Prix - Practice 2 [v3.6.0]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['1', '4', '5', '6', '10', '12', '14', '16', '18', '22', '23', '27', '30', '31', '43', '44', '55', '63', '81', '87']
# core           INFO 	Loading data for Azerbaijan Grand Prix - Qualifying [v3.6.0]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['1', '55', '30', '12', '63', '22', '4', '6', '81', '16', '14', '44', '5', '18', '87', '43', '27', '10', '23', '31']

# %%
# Load your sessions
sessions_data = {
    'fp2': {'session': fp2_session, 'session_name': 'Baku GP', 'year': 2025, 'session_type': 'FP2'},
    'qualifying': {'session': q_session, 'session_name': 'Baku GP', 'year': 2025, 'session_type': 'Q'}
}

# Create the analyzer
cross_session_t = f1.cross_session_telemetry.CrossSessionTelemetry(sessions_data)

# Compare laps with custom channels
cross_session_t.compare_laps([
    ('fp2', 'HAM', 'fastest'),
    ('qualifying', 'HAM', 'fastest')
], channels=['Speed', 'Throttle', 'Delta'])

# %%
f1.session_delta_chart.create_session_delta_chart(fp2_session, q_session, "FP2 vs Qualifying")
